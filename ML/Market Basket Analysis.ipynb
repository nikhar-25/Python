# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
#reading the dataset 
df= pd.read_excel('Online_Retail.xlsx')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # DATA PREPARATION

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df.head(20)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745            POPPY'S PLAYHOUSE BEDROOM         6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
df.shape
# Out:
# (541909, 8)

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
#seeing transsaction of patricular country
basket_france = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
#view
basket_france.head(20)
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# 537468                         24.0                         0.0
# 537693                          0.0                         0.0
# 537897                          0.0                         0.0
# 537967                          0.0                         0.0
# 538008                          0.0                         0.0
# 538093                          0.0                         0.0
# 538196                          0.0                         0.0
# 539050                          0.0                         0.0
# ...

# %%
#converting all positive vaues to 1 and everything else to 0
def my_encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
    
basket_france_sets = basket_france.applymap(my_encode_units)
basket_france_sets.drop('POSTAGE', inplace=True, axis=1) #Remove "postage" as an item

# %%
#Generatig frequent itemsets
my_frequent_itemsets = apriori(basket_france_sets, min_support=0.07, use_colnames=True)

# %%
#generating rules
my_rules = association_rules(my_frequent_itemsets, metric="lift", min_threshold=1)

# %%
#viewing top 100 rules
my_rules.head(100)
# Out:
#                                           antecedents  \
# 0                     (PLASTERS IN TIN CIRCUS PARADE)
# 1                          (PLASTERS IN TIN SPACEBOY)
# 2                     (PLASTERS IN TIN CIRCUS PARADE)
# 3                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 4                          (PLASTERS IN TIN SPACEBOY)
# 5                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 6                       (SET/6 RED SPOTTY PAPER CUPS)
# 7                (SET/20 RED RETROSPOT PAPER NAPKINS)
# 8                     (SET/6 RED SPOTTY PAPER PLATES)
# 9                (SET/20 RED RETROSPOT PAPER NAPKINS)
# 10                      (SET/6 RED SPOTTY PAPER CUPS)
# 11                    (SET/6 RED SPOTTY PAPER PLATES)
# 12  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 13  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 14  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 15                      (SET/6 RED SPOTTY PAPER CUPS)
# ...

# %%
#Filtering rules based on condition
my_rules[ (my_rules['lift'] >= 8) &
       (my_rules['confidence'] >= 0.7) ]
# Out:
#                                           antecedents  \
# 10                      (SET/6 RED SPOTTY PAPER CUPS)
# 11                    (SET/6 RED SPOTTY PAPER PLATES)
# 13  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 14  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 15                      (SET/6 RED SPOTTY PAPER CUPS)
# 16                    (SET/6 RED SPOTTY PAPER PLATES)
#
#                                           consequents  antecedent support  \
# 10                    (SET/6 RED SPOTTY PAPER PLATES)            0.117137
# 11                      (SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 13                    (SET/6 RED SPOTTY PAPER PLATES)            0.086768
# 14                      (SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 15  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...            0.117137
# 16  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...            0.108460
#
# ...
